# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import statsmodels.api as sm
from statsmodels.tools.eval_measures import mse, rmse
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sqlalchemy import create_engine
import scipy.stats as stats


import warnings
warnings.filterwarnings('ignore')

postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'houseprices'

# %%
engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))
df = pd.read_sql_query('select * from houseprices',con=engine)

# no need for an open connection, as we're only doing a single query
engine.dispose()


df.head()
# Out:
#    id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 0   1          60       RL         65.0     8450   Pave  None      Reg
# 1   2          20       RL         80.0     9600   Pave  None      Reg
# 2   3          60       RL         68.0    11250   Pave  None      IR1
# 3   4          70       RL         60.0     9550   Pave  None      IR1
# 4   5          60       RL         84.0    14260   Pave  None      IR1
#
#   landcontour utilities  ... poolarea poolqc fence miscfeature miscval mosold  \
# 0         Lvl    AllPub  ...        0   None  None        None       0      2
# 1         Lvl    AllPub  ...        0   None  None        None       0      5
# 2         Lvl    AllPub  ...        0   None  None        None       0      9
# 3         Lvl    AllPub  ...        0   None  None        None       0      2
# 4         Lvl    AllPub  ...        0   None  None        None       0     12
#
#   yrsold  saletype  salecondition  saleprice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
#allow us to see all columns and rows w/out truncation
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.3f}'.format

# %%
df.isnull().sum() / df.isnull().count() * 100
# Out:
# id               0.000
# mssubclass       0.000
# mszoning         0.000
# lotfrontage     17.740
# lotarea          0.000
# street           0.000
# alley           93.767
# lotshape         0.000
# landcontour      0.000
# utilities        0.000
# lotconfig        0.000
# landslope        0.000
# neighborhood     0.000
# condition1       0.000
# condition2       0.000
# bldgtype         0.000
# housestyle       0.000
# overallqual      0.000
# overallcond      0.000
# yearbuilt        0.000
# yearremodadd     0.000
# roofstyle        0.000
# roofmatl         0.000
# exterior1st      0.000
# exterior2nd      0.000
# masvnrtype       0.548
# masvnrarea       0.548
# exterqual        0.000
# extercond        0.000
# foundation       0.000
# bsmtqual         2.534
# bsmtcond         2.534
# bsmtexposure     2.603
# bsmtfintype1     2.534
# bsmtfinsf1       0.000
# bsmtfintype2     2.603
# bsmtfinsf2       0.000
# bsmtunfsf        0.000
# totalbsmtsf      0.000
# heating          0.000
# heatingqc        0.000
# centralair       0.000
# electrical       0.068
# firstflrsf       0.000
# secondflrsf      0.000
# lowqualfinsf     0.000
# grlivarea        0.000
# bsmtfullbath     0.000
# bsmthalfbath     0.000
# fullbath         0.000
# halfbath         0.000
# bedroomabvgr     0.000
# kitchenabvgr     0.000
# kitchenqual      0.000
# totrmsabvgrd     0.000
# functional       0.000
# fireplaces       0.000
# fireplacequ     47.260
# garagetype       5.548
# garageyrblt      5.548
# garagefinish     5.548
# garagecars       0.000
# garagearea       0.000
# garagequal       5.548
# garagecond       5.548
# paveddrive       0.000
# wooddecksf       0.000
# openporchsf      0.000
# enclosedporch    0.000
# threessnporch    0.000
# screenporch      0.000
# poolarea         0.000
# poolqc          99.521
# fence           80.753
# miscfeature     96.301
# miscval          0.000
# mosold           0.000
# yrsold           0.000
# saletype         0.000
# salecondition    0.000
# saleprice        0.000
# dtype: float64

# %%
#fill in some missing values
df.lotfrontage.fillna(df.lotfrontage.median(), inplace=True)
#Alley NA's means there's no alley access
df.alley.fillna('No Access', inplace=True)
#basement NA's == no basement
df.bsmtqual.fillna('No Basement', inplace=True)
df.bsmtcond.fillna('No Basement', inplace=True)
df.bsmtexposure.fillna('No Basement', inplace=True)
df.bsmtfintype1.fillna('No Basement', inplace=True)
df.bsmtfintype2.fillna('No Basement', inplace=True)
#fireplace na means no fireplace
df.fireplacequ.fillna('No Fireplace', inplace=True)
#garage--see above
df.garagetype.fillna('No Garage', inplace=True)
df.garagefinish.fillna('No Garage', inplace=True)
df.garagequal.fillna('No Garage', inplace=True)
df.garagecond.fillna('No Garage', inplace=True)
df.garageyrblt.fillna('No Year', inplace=True)
#these are unique, but same as above
df.poolqc.fillna('No pool', inplace=True)
df.fence.fillna('No Fence', inplace=True)
df.miscfeature.fillna('None unique', inplace=True)
#masonry is either 0 or not there
df.masvnrtype.fillna('No masonry', inplace=True)
df.masvnrarea.fillna(0, inplace=True)

# %%
df.isnull().sum() / df.isnull().count() * 100
# Out:
# id              0.000
# mssubclass      0.000
# mszoning        0.000
# lotfrontage     0.000
# lotarea         0.000
# street          0.000
# alley           0.000
# lotshape        0.000
# landcontour     0.000
# utilities       0.000
# lotconfig       0.000
# landslope       0.000
# neighborhood    0.000
# condition1      0.000
# condition2      0.000
# bldgtype        0.000
# housestyle      0.000
# overallqual     0.000
# overallcond     0.000
# yearbuilt       0.000
# yearremodadd    0.000
# roofstyle       0.000
# roofmatl        0.000
# exterior1st     0.000
# exterior2nd     0.000
# masvnrtype      0.000
# masvnrarea      0.000
# exterqual       0.000
# extercond       0.000
# foundation      0.000
# bsmtqual        0.000
# bsmtcond        0.000
# bsmtexposure    0.000
# bsmtfintype1    0.000
# bsmtfinsf1      0.000
# bsmtfintype2    0.000
# bsmtfinsf2      0.000
# bsmtunfsf       0.000
# totalbsmtsf     0.000
# heating         0.000
# heatingqc       0.000
# centralair      0.000
# electrical      0.068
# firstflrsf      0.000
# secondflrsf     0.000
# lowqualfinsf    0.000
# grlivarea       0.000
# bsmtfullbath    0.000
# bsmthalfbath    0.000
# fullbath        0.000
# halfbath        0.000
# bedroomabvgr    0.000
# kitchenabvgr    0.000
# kitchenqual     0.000
# totrmsabvgrd    0.000
# functional      0.000
# fireplaces      0.000
# fireplacequ     0.000
# garagetype      0.000
# garageyrblt     0.000
# garagefinish    0.000
# garagecars      0.000
# garagearea      0.000
# garagequal      0.000
# garagecond      0.000
# paveddrive      0.000
# wooddecksf      0.000
# openporchsf     0.000
# enclosedporch   0.000
# threessnporch   0.000
# screenporch     0.000
# poolarea        0.000
# poolqc          0.000
# fence           0.000
# miscfeature     0.000
# miscval         0.000
# mosold          0.000
# yrsold          0.000
# saletype        0.000
# salecondition   0.000
# saleprice       0.000
# dtype: float64

# %% [markdown]
# Now that we've handled almost all missing values, let's work on some univariate analysis.

# %%
columns = df.columns.tolist()
columns.remove('id')
columns.remove('mssubclass')

# %%
for column in columns:
    print('{} -- {}'.format(column, df[column].nunique()))
# Out:
# mszoning -- 5
# lotfrontage -- 110
# lotarea -- 1073
# street -- 2
# alley -- 3
# lotshape -- 4
# landcontour -- 4
# utilities -- 2
# lotconfig -- 5
# landslope -- 3
# neighborhood -- 25
# condition1 -- 9
# condition2 -- 8
# bldgtype -- 5
# housestyle -- 8
# overallqual -- 10
# overallcond -- 9
# yearbuilt -- 112
# yearremodadd -- 61
# roofstyle -- 6
# roofmatl -- 8
# exterior1st -- 15
# exterior2nd -- 16
# masvnrtype -- 5
# masvnrarea -- 327
# exterqual -- 4
# extercond -- 5
# foundation -- 6
# bsmtqual -- 5
# bsmtcond -- 5
# bsmtexposure -- 5
# bsmtfintype1 -- 7
# bsmtfinsf1 -- 637
# bsmtfintype2 -- 7
# bsmtfinsf2 -- 144
# bsmtunfsf -- 780
# totalbsmtsf -- 721
# heating -- 6
# heatingqc -- 5
# centralair -- 2
# electrical -- 5
# firstflrsf -- 753
# secondflrsf -- 417
# lowqualfinsf -- 24
# grlivarea -- 861
# bsmtfullbath -- 4
# bsmthalfbath -- 3
# fullbath -- 4
# halfbath -- 3
# bedroomabvgr -- 8
# kitchenabvgr -- 4
# kitchenqual -- 4
# totrmsabvgrd -- 12
# functional -- 7
# fireplaces -- 4
# fireplacequ -- 6
# garagetype -- 7
# garageyrblt -- 98
# garagefinish -- 4
# garagecars -- 5
# garagearea -- 441
# garagequal -- 6
# garagecond -- 6
# paveddrive -- 3
# wooddecksf -- 274
# openporchsf -- 202
# enclosedporch -- 120
# threessnporch -- 20
# screenporch -- 76
# poolarea -- 8
# poolqc -- 4
# fence -- 5
# miscfeature -- 5
# miscval -- 21
# mosold -- 12
# yrsold -- 5
# saletype -- 9
# salecondition -- 6
# saleprice -- 663

# %%
#split our variables into continuous and categorical/discrete columns
cat_cols = []
cont_cols = []

for column in columns:
    if (column[:4] != 'year' and df[column].nunique() < 100):
        cat_cols.append(column)
    else:
        cont_cols.append(column)     

#some minor changes from our rules
cat_cols.remove('screenporch')
cont_cols.append('screenporch')

cat_cols.remove('garageyrblt')

# %%
#let's inspect our categorical values
for column in cat_cols:
    plt.figure(figsize=(18, 6))
    
    plt.subplot(1, 2, 1)
    sns.countplot(df[column])
    plt.title('{}'.format(column))
    plt.xticks(rotation='vertical')
    
    plt.subplot(1, 2, 2)
    sns.barplot(x=column, y='saleprice', data=df)
    plt.title('{} vs salesprice'.format(column))
    plt.xticks(rotation='vertical')
    
    plt.show()

# %%
for column in cont_cols:
    plt.figure(figsize=(18, 6))
    
    plt.subplot(1, 2, 1)
    corr, p_value = stats.pearsonr(df['saleprice'], df[column])
    print('The coefficient is {}'.format(corr))
    sns.regplot(x=column, y='saleprice', data=df)
    plt.title('{} vs saleprice'.format(column))
    
    plt.subplot(1, 2, 2)
    sns.distplot(df[column])
    plt.title('{}'.format(column))
    
    plt.show()
# Out:
# The coefficient is 0.33477085313975996
# The coefficient is 0.2638433538714056
# The coefficient is 0.522897332879497
# The coefficient is 0.5071009671113861
# The coefficient is 0.4726144990045737
# The coefficient is 0.3864198062421533
# The coefficient is -0.01137812145021514
# The coefficient is 0.2144791055469689
# The coefficient is 0.6135805515591953
# The coefficient is 0.6058521846919147
# The coefficient is 0.3193338028320678
# The coefficient is 0.708624477612652
# The coefficient is 0.6234314389183616
# The coefficient is 0.3244134445681299
# The coefficient is 0.3158562271160552
# The coefficient is -0.12857795792595675
# The coefficient is 1.0
# The coefficient is 0.11144657114291123

# %%
#create our continuous dataframe
cont_df = df[['totalbsmtsf', 'firstflrsf', 'grlivarea', 'garagearea', 'saleprice']]

# %%
sns.heatmap(cont_df.corr(), annot=True, linewidth=0.5)
plt.show()

# %%
#drop firstflrsf
cont_df = cont_df.drop(columns=['firstflrsf', 'garagearea'])

# %%
#we only have 1 cat_df that needs get_dummies
dummies = pd.get_dummies(df['kitchenqual'], drop_first=True)
#create our categorical df
cat_df = pd.concat([dummies, df.overallqual, df.totrmsabvgrd, df.fireplaces, df.garagecars], axis=1)

# %%
#combine the 2 dataframes
final_df = pd.concat([cont_df, cat_df], axis=1)

# %%
sns.heatmap(final_df.corr(), annot=True, linewidth=0.5)
plt.show()

# %% [markdown]
# Those look pretty good, let's start building our OLS lr model!

# %%
X = final_df.drop(columns='saleprice')
y = final_df['saleprice']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

print("The number of observations in training set is {}".format(X_train.shape[0]))
print("The number of observations in test set is {}".format(X_test.shape[0]))
# Out:
# The number of observations in training set is 1168
# The number of observations in test set is 292

# %% [markdown]
# Let's compare our training data with our testing data.

# %%
# We add constant to the model as it's a best practice
# to do so ever ytime!
X_train = sm.add_constant(X_train)

# We fit an OLS model using statsmodels
results = sm.OLS(y_train, X_train).fit()

# We print the summary results
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.782
# Model:                            OLS   Adj. R-squared:                  0.780
# Method:                 Least Squares   F-statistic:                     461.3
# Date:                Sat, 13 Jul 2019   Prob (F-statistic):               0.00
# Time:                        11:05:39   Log-Likelihood:                -13948.
# No. Observations:                1168   AIC:                         2.792e+04
# Df Residuals:                    1158   BIC:                         2.797e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         3605.0600   1.05e+04      0.343      0.732    -1.7e+04    2.42e+04
# totalbsmtsf     20.9657      3.111      6.738      0.000      14.861      27.070
# grlivarea       43.8235      4.382     10.001      0.000      35.226      52.421
# Fa           -6.219e+04   9182.915     -6.772      0.000   -8.02e+04   -4.42e+04
# Gd           -4.722e+04   4801.982     -9.834      0.000   -5.66e+04   -3.78e+04
# TA           -6.205e+04   5448.528    -11.388      0.000   -7.27e+04   -5.14e+04
# overallqual   1.818e+04   1313.446     13.838      0.000    1.56e+04    2.08e+04
# totrmsabvgrd  -978.0770   1234.333     -0.792      0.428   -3399.856    1443.702
# fireplaces    7927.5512   1963.328      4.038      0.000    4075.473    1.18e+04
# garagecars    1.756e+04   1908.721      9.198      0.000    1.38e+04    2.13e+04
# ==============================================================================
# Omnibus:                      439.171   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            42053.293
# Skew:                          -0.756   Prob(JB):                         0.00
# Kurtosis:                      32.357   Cond. No.                     2.44e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Ok, our training data is loaded. Let's see how it performs on our test data.

# %%
# We add constant to the model as it's a best practice
# to do so every time!
X_test = sm.add_constant(X_test)

# We are making predictions here
y_preds = results.predict(X_test)

plt.scatter(y_test, y_preds)
plt.plot(y_test, y_test, color="red")
plt.xlabel("true values")
plt.ylabel("predicted values")
plt.title("Charges: true and predicted values")
plt.show()

print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, y_preds)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, y_preds)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, y_preds)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - y_preds) / y_test)) * 100))
# Out:
# Mean absolute error of the prediction is: 23064.79050924594
# Mean squared error of the prediction is: 1153654815.4740884
# Root mean squared error of the prediction is: 33965.494482990944
# Mean absolute percentage error of the prediction is: 13.790122207798605

# %% [markdown]
# It seems the model is having a hard time predicting the larger values. We also had on feature that had a high p_value. Let's see how our model performs once we remove it.

# %% [markdown]
# ## Ridge Regression

# %% [markdown]
# We have a 0 r-squared on the training set and a negative on the test set. This seems like we're overfitting?

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score

stds = []
#let's tune our alpha by finding the most consistent measure via cross validation
for i in range(1, 100):
    ridgeregr = Ridge(alpha=10**i) 
    stds.append(cross_val_score(ridgeregr, X, y, cv=10).std())
    
print(min(stds), stds.index(min(stds)) + 1)
# Out:
# 0.005522989288948871 11

# %%
#reload our train/testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

print("The number of observations in training set is {}".format(X_train.shape[0]))
print("The number of observations in test set is {}".format(X_test.shape[0]))
# Out:
# The number of observations in training set is 1168
# The number of observations in test set is 292

# %%
# Fitting a ridge regression model. Alpha is the regularization
# parameter (usually called lambda). As alpha gets larger, parameter
# shrinkage grows more pronounced.
ridgeregr = Ridge(alpha=10*11) 
ridgeregr.fit(X_train, y_train)

# We are making predictions here
y_preds_train = ridgeregr.predict(X_train)
y_preds_test = ridgeregr.predict(X_test)

print("R-squared of the model on the training set is: {}".format(ridgeregr.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model on the test set is: {}".format(ridgeregr.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - y_preds_test) / y_test)) * 100))
# Out:
# R-squared of the model on the training set is: 0.7652523655389095
# -----Test set statistics-----
# R-squared of the model on the test set is: 0.7989832717926167
# Mean absolute error of the prediction is: 23652.660552382164
# Mean squared error of the prediction is: 1250633057.4941924
# Root mean squared error of the prediction is: 35364.29071102929
# Mean absolute percentage error of the prediction is: 14.25056522006545

# %% [markdown]
# It looks like our ridge regression performs a little worse. This could be understandable as none of our coefficients are that big. So good news!

# %% [markdown]
# ## Lasso regression

# %%
from sklearn.linear_model import Lasso

stds = []
for i in range(1, 100):
    lassoregr = Lasso(alpha=10**i) 
    stds.append(cross_val_score(lassoregr, X, y, cv=10).std())

print(min(stds), stds.index(min(stds)) + 1)
# Out:
# 0.0055732211170826 8

# %%
#reload our train/testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

print("The number of observations in training set is {}".format(X_train.shape[0]))
print("The number of observations in test set is {}".format(X_test.shape[0]))\
# Out:
# The number of observations in training set is 1168
# The number of observations in test set is 292

# %%
# Fitting a lasso regression model. Alpha is the regularization
# parameter (usually called lambda). As alpha gets larger, parameter
# shrinkage grows more pronounced.
lassoregr = Lasso(alpha=10**8) 
lassoregr.fit(X_train, y_train)

# We are making predictions here
y_preds_train = ridgeregr.predict(X_train)
y_preds_test = ridgeregr.predict(X_test)

print("R-squared of the model on the training set is: {}".format(ridgeregr.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model on the test set is: {}".format(ridgeregr.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - y_preds_test) / y_test)) * 100))
# Out:
# R-squared of the model on the training set is: 0.7652523655389095
# -----Test set statistics-----
# R-squared of the model on the test set is: 0.7989832717926167
# Mean absolute error of the prediction is: 23652.660552382164
# Mean squared error of the prediction is: 1250633057.4941924
# Root mean squared error of the prediction is: 35364.29071102929
# Mean absolute percentage error of the prediction is: 14.25056522006545

# %% [markdown]
# Ok, this seems to performing slightly worse than our original model. This makes sense due to the lack of complexity in our model.

# %% [markdown]
# ## Elastic Net

# %%
from sklearn.linear_model import ElasticNet

#tune the alpha and l1
stds = []
items = []
l1 = []
for i in range(1, 100):
    for j in np.arange(0.1, 1.0, 0.1):
        elasticregr = ElasticNet(alpha=10**i ,l1_ratio=j) 
        stds.append(cross_val_score(elasticregr, X, y, cv=10).std())
        items.append(i)
        l1.append(j)

index = stds.index(min(stds))
print(min(stds), stds[index], items[index], l1[index])
# Out:
# 0.005515695397536605 0.005515695397536605 8 0.2

# %%
elasticregr = ElasticNet(alpha=10**8, l1_ratio=0.2) 
elasticregr.fit(X_train, y_train)



# We are making predictions here
y_preds_train = elasticregr.predict(X_train)
y_preds_test = elasticregr.predict(X_test)

print("R-squared of the model on the training set is: {}".format(elasticregr.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model on the test set is: {}".format(elasticregr.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - y_preds_test) / y_test)) * 100))
# Out:
# R-squared of the model on the training set is: 0.0013153692979032128
# -----Test set statistics-----
# R-squared of the model on the test set is: 0.0008233038052821717
# Mean absolute error of the prediction is: 57353.02475161659
# Mean squared error of the prediction is: 6216415010.246139
# Root mean squared error of the prediction is: 78844.24525763525
# Mean absolute percentage error of the prediction is: 37.61033418030702

# %% [markdown]
# This one does the worse by far! Very low r-squared values and high mean absolute percentage error.

# %% [markdown]
# ## Summary:
#
# It seems that regularizing our model doesn't seem to improve our results. As we tune and tweak our model, we should consider using these. Especially if we get a very large (or very small) coefficient!
